# %% [markdown]
# <a href="https://colab.research.google.com/github/ShriKant010102/Deep_Learning/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to c:\users\vicky\appdata\local\temp\pip-req-build-8_1ny8_k
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: requests in c:\users\vicky\appdata\local\programs\python\python312\lib\site-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in c:\users\vicky\appdata\local\programs\python\python312\lib\site-packages (from mnist1d==0.0.2.post16) (2.1.0)
# Requirement already satisfied: matplotlib in c:\users\vicky\appdata\local\programs\python\python312\lib\site-packages (from mnist1d==0.0.2.post16) (3.9.2)
# Requirement already satisfied: scipy in c:\users\vicky\appdata\local\programs\python\python312\lib\site-packages (from mnist1d==0.0.2.post16) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vicky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\vicky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vicky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vicky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\vicky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\vicky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vicky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vicky\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\vicky\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vicky\appdata\local\programs\python\python312\lib\site-packages (from requests->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vicky\appdata\local\programs\python\python312\lib\site-packages (from requests->mnist1d==0.0.2.post16) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vicky\appdata\local\programs\python\python312\lib\site-packages (from requests->mnist1d==0.0.2.post16) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vicky\appdata\local\programs\python\python312\lib\site-packages (from requests->mnist1d==0.0.2.post16) (2024.6.2)
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d 'C:\Users\VICKY\AppData\Local\Temp\pip-req-build-8_1ny8_k'

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.289500, train error 88.80,  test loss 2.287376, test error 88.03
# Epoch   100, train loss 1.913779, train error 71.70,  test loss 1.764906, test error 69.53
# Epoch   200, train loss 1.909701, train error 72.60,  test loss 1.743452, test error 69.65
# Epoch   300, train loss 1.904141, train error 72.00,  test loss 1.740671, test error 69.00
# Epoch   400, train loss 1.907228, train error 71.28,  test loss 1.734867, test error 69.18
# Epoch   500, train loss 1.907323, train error 71.78,  test loss 1.734271, test error 68.70
# Epoch   600, train loss 1.902389, train error 71.80,  test loss 1.732318, test error 69.55
# Epoch   700, train loss 1.901801, train error 71.62,  test loss 1.734828, test error 69.72
# Epoch   800, train loss 1.905535, train error 71.12,  test loss 1.737698, test error 69.47
# Epoch   900, train loss 1.901616, train error 71.55,  test loss 1.731566, test error 68.78
# Training model with   4 hidden variables
# Epoch     0, train loss 2.308884, train error 91.03,  test loss 2.306664, test error 92.10
# Epoch   100, train loss 1.857455, train error 69.12,  test loss 1.723465, test error 66.45
# Epoch   200, train loss 1.825697, train error 68.07,  test loss 1.699604, test error 66.22
# Epoch   300, train loss 1.816341, train error 67.47,  test loss 1.694085, test error 65.60
# Epoch   400, train loss 1.814289, train error 66.72,  test loss 1.696463, test error 64.75
# Epoch   500, train loss 1.811505, train error 66.57,  test loss 1.698403, test error 64.43
# Epoch   600, train loss 1.805889, train error 65.45,  test loss 1.689318, test error 64.32
# Epoch   700, train loss 1.801155, train error 65.90,  test loss 1.681744, test error 64.03
# Epoch   800, train loss 1.798201, train error 65.43,  test loss 1.675679, test error 63.97
# Epoch   900, train loss 1.796545, train error 65.18,  test loss 1.673539, test error 64.20
# Training model with   6 hidden variables
# Epoch     0, train loss 2.272120, train error 86.53,  test loss 2.253024, test error 85.18
# Epoch   100, train loss 1.672943, train error 61.92,  test loss 1.484722, test error 57.53
# Epoch   200, train loss 1.635137, train error 59.15,  test loss 1.474977, test error 56.50
# Epoch   300, train loss 1.622013, train error 59.08,  test loss 1.464321, test error 56.65
# Epoch   400, train loss 1.612218, train error 58.67,  test loss 1.471334, test error 56.80
# Epoch   500, train loss 1.606231, train error 58.30,  test loss 1.475579, test error 56.42
# Epoch   600, train loss 1.604779, train error 58.28,  test loss 1.472309, test error 56.62
# Epoch   700, train loss 1.604580, train error 57.78,  test loss 1.474630, test error 56.97
# Epoch   800, train loss 1.602450, train error 58.12,  test loss 1.475102, test error 57.35
# Epoch   900, train loss 1.602252, train error 58.47,  test loss 1.474460, test error 56.70
# Training model with   8 hidden variables
# Epoch     0, train loss 2.277091, train error 84.80,  test loss 2.271508, test error 85.90
# Epoch   100, train loss 1.573954, train error 55.55,  test loss 1.408631, test error 53.92
# Epoch   200, train loss 1.555636, train error 54.83,  test loss 1.407463, test error 53.55
# Epoch   300, train loss 1.541674, train error 54.38,  test loss 1.397819, test error 52.30
# Epoch   400, train loss 1.531301, train error 54.10,  test loss 1.398594, test error 53.25
# Epoch   500, train loss 1.521659, train error 53.55,  test loss 1.395806, test error 53.00
# Epoch   600, train loss 1.530481, train error 54.62,  test loss 1.407493, test error 53.47
# Epoch   700, train loss 1.516857, train error 53.55,  test loss 1.404837, test error 52.17
# Epoch   800, train loss 1.527431, train error 53.80,  test loss 1.419296, test error 52.90
# Epoch   900, train loss 1.515280, train error 53.53,  test loss 1.408547, test error 52.42
# Training model with  10 hidden variables
# Epoch     0, train loss 2.146305, train error 80.18,  test loss 2.097511, test error 78.90
# Epoch   100, train loss 1.457555, train error 49.78,  test loss 1.295041, test error 47.67
# Epoch   200, train loss 1.398695, train error 47.08,  test loss 1.242127, test error 46.15
# Epoch   300, train loss 1.388272, train error 47.10,  test loss 1.246531, test error 46.15
# Epoch   400, train loss 1.373438, train error 46.05,  test loss 1.244722, test error 45.67
# Epoch   500, train loss 1.365010, train error 45.88,  test loss 1.242167, test error 46.25
# Epoch   600, train loss 1.356691, train error 45.53,  test loss 1.254839, test error 45.85
# Epoch   700, train loss 1.342090, train error 45.60,  test loss 1.248698, test error 45.78
# Epoch   800, train loss 1.342476, train error 45.45,  test loss 1.246234, test error 46.00
# Epoch   900, train loss 1.339601, train error 45.53,  test loss 1.274498, test error 46.53
# Training model with  14 hidden variables
# Epoch     0, train loss 2.123552, train error 79.38,  test loss 2.096504, test error 78.28
# Epoch   100, train loss 1.478587, train error 51.80,  test loss 1.432053, test error 53.97
# Epoch   200, train loss 1.386039, train error 47.78,  test loss 1.419866, test error 52.92
# Epoch   300, train loss 1.351445, train error 46.45,  test loss 1.431718, test error 52.80
# Epoch   400, train loss 1.334151, train error 45.72,  test loss 1.454860, test error 53.47
# Epoch   500, train loss 1.327186, train error 45.83,  test loss 1.463326, test error 53.50
# Epoch   600, train loss 1.323220, train error 45.65,  test loss 1.481025, test error 53.75
# Epoch   700, train loss 1.315314, train error 44.88,  test loss 1.488695, test error 53.72
# Epoch   800, train loss 1.311810, train error 44.95,  test loss 1.523448, test error 53.60
# Epoch   900, train loss 1.315435, train error 45.25,  test loss 1.542097, test error 54.40
# Training model with  18 hidden variables
# Epoch     0, train loss 2.144718, train error 81.47,  test loss 2.098636, test error 79.90
# Epoch   100, train loss 1.407422, train error 48.12,  test loss 1.436101, test error 53.83
# Epoch   200, train loss 1.311272, train error 44.97,  test loss 1.442071, test error 53.35
# Epoch   300, train loss 1.265964, train error 43.28,  test loss 1.484227, test error 52.80
# Epoch   400, train loss 1.240920, train error 42.28,  test loss 1.520273, test error 52.97
# Epoch   500, train loss 1.216880, train error 41.42,  test loss 1.523331, test error 52.22
# Epoch   600, train loss 1.208324, train error 41.45,  test loss 1.568093, test error 53.17
# Epoch   700, train loss 1.195724, train error 41.33,  test loss 1.600531, test error 53.28
# Epoch   800, train loss 1.191611, train error 40.62,  test loss 1.610604, test error 53.00
# Epoch   900, train loss 1.182876, train error 41.03,  test loss 1.655600, test error 53.08
# Training model with  22 hidden variables
# Epoch     0, train loss 2.170257, train error 79.95,  test loss 2.134093, test error 78.32
# Epoch   100, train loss 1.293445, train error 43.70,  test loss 1.377494, test error 50.55
# Epoch   200, train loss 1.164695, train error 38.58,  test loss 1.415369, test error 50.83
# Epoch   300, train loss 1.115352, train error 38.03,  test loss 1.499845, test error 51.67
# Epoch   400, train loss 1.069387, train error 36.10,  test loss 1.539613, test error 51.83
# Epoch   500, train loss 1.036195, train error 34.20,  test loss 1.594927, test error 52.53
# Epoch   600, train loss 1.017541, train error 34.00,  test loss 1.632880, test error 52.33
# Epoch   700, train loss 1.000824, train error 33.22,  test loss 1.684900, test error 52.40
# Epoch   800, train loss 1.001258, train error 33.75,  test loss 1.739633, test error 53.70
# Epoch   900, train loss 0.989158, train error 33.32,  test loss 1.792676, test error 53.90
# Training model with  26 hidden variables
# Epoch     0, train loss 2.246482, train error 83.25,  test loss 2.254724, test error 84.07
# Epoch   100, train loss 1.204218, train error 38.05,  test loss 1.356371, test error 49.08
# Epoch   200, train loss 1.070440, train error 33.95,  test loss 1.477301, test error 52.15
# Epoch   300, train loss 0.999889, train error 33.03,  test loss 1.594881, test error 52.47
# Epoch   400, train loss 0.955384, train error 31.32,  test loss 1.738495, test error 54.40
# Epoch   500, train loss 0.919324, train error 30.18,  test loss 1.829217, test error 54.70
# Epoch   600, train loss 0.907379, train error 30.10,  test loss 1.959062, test error 56.03
# Epoch   700, train loss 0.888571, train error 30.35,  test loss 2.012010, test error 54.83
# Epoch   800, train loss 0.858116, train error 29.00,  test loss 2.118798, test error 55.05
# Epoch   900, train loss 0.855472, train error 29.12,  test loss 2.196165, test error 56.40
# Training model with  30 hidden variables
# Epoch     0, train loss 2.095738, train error 78.05,  test loss 2.035478, test error 76.40
# Epoch   100, train loss 1.105405, train error 36.55,  test loss 1.267072, test error 46.55
# Epoch   200, train loss 0.935458, train error 31.00,  test loss 1.414905, test error 47.30
# Epoch   300, train loss 0.856917, train error 27.80,  test loss 1.569152, test error 49.60
# Epoch   400, train loss 0.783202, train error 25.43,  test loss 1.687546, test error 50.03
# Epoch   500, train loss 0.763627, train error 25.65,  test loss 1.810515, test error 50.80
# Epoch   600, train loss 0.745754, train error 24.50,  test loss 1.937020, test error 51.05
# Epoch   700, train loss 0.705696, train error 22.62,  test loss 2.060732, test error 53.65
# Epoch   800, train loss 0.700611, train error 22.65,  test loss 2.151833, test error 53.30
# Epoch   900, train loss 0.664828, train error 21.45,  test loss 2.242279, test error 53.50
# Training model with  35 hidden variables
# Epoch     0, train loss 2.118773, train error 79.68,  test loss 2.072540, test error 78.38
# Epoch   100, train loss 1.007968, train error 33.05,  test loss 1.365987, test error 48.55
# Epoch   200, train loss 0.786935, train error 25.75,  test loss 1.654943, test error 51.03
# Epoch   300, train loss 0.706113, train error 23.88,  test loss 2.022136, test error 52.83
# Epoch   400, train loss 0.618009, train error 20.50,  test loss 2.295433, test error 53.72
# Epoch   500, train loss 0.584122, train error 18.93,  test loss 2.560117, test error 54.53
# Epoch   600, train loss 0.528750, train error 17.93,  test loss 2.864023, test error 54.10
# Epoch   700, train loss 0.540002, train error 19.18,  test loss 3.221478, test error 56.03
# Epoch   800, train loss 0.479843, train error 16.30,  test loss 3.440848, test error 55.67
# Epoch   900, train loss 0.479171, train error 16.05,  test loss 3.639554, test error 55.65
# Training model with  40 hidden variables
# Epoch     0, train loss 2.147872, train error 78.85,  test loss 2.117191, test error 78.60
# Epoch   100, train loss 0.910796, train error 29.88,  test loss 1.426077, test error 49.92
# Epoch   200, train loss 0.596250, train error 20.07,  test loss 2.013958, test error 52.88
# Epoch   300, train loss 0.455744, train error 15.53,  test loss 2.744479, test error 54.45
# Epoch   400, train loss 0.363050, train error 12.07,  test loss 3.465695, test error 54.47
# Epoch   500, train loss 0.327923, train error 11.57,  test loss 4.308803, test error 55.08
# Epoch   600, train loss 0.271789, train error 9.20,  test loss 5.221785, test error 56.58
# Epoch   700, train loss 0.257990, train error 8.72,  test loss 5.933387, test error 55.78
# Epoch   800, train loss 0.211591, train error 7.78,  test loss 6.735379, test error 56.60
# Epoch   900, train loss 0.229013, train error 7.88,  test loss 7.434697, test error 56.35
# Training model with  45 hidden variables
# Epoch     0, train loss 2.105372, train error 77.85,  test loss 2.062637, test error 76.65
# Epoch   100, train loss 0.825028, train error 27.88,  test loss 1.518156, test error 50.40
# Epoch   200, train loss 0.504095, train error 15.47,  test loss 2.175734, test error 51.70
# Epoch   300, train loss 0.322216, train error 9.25,  test loss 3.083835, test error 53.95
# Epoch   400, train loss 0.227556, train error 6.97,  test loss 4.238508, test error 55.15
# Epoch   500, train loss 0.163551, train error 4.82,  test loss 5.618449, test error 56.62
# Epoch   600, train loss 0.196892, train error 6.70,  test loss 6.898352, test error 58.53
# Epoch   700, train loss 0.019021, train error 0.03,  test loss 7.890954, test error 58.08
# Epoch   800, train loss 0.010144, train error 0.00,  test loss 8.766344, test error 58.05
# Epoch   900, train loss 0.007105, train error 0.00,  test loss 9.360223, test error 58.05
# Training model with  50 hidden variables
# Epoch     0, train loss 2.078076, train error 76.88,  test loss 2.025423, test error 76.10
# Epoch   100, train loss 0.722159, train error 22.38,  test loss 1.507372, test error 49.92
# Epoch   200, train loss 0.365562, train error 10.47,  test loss 2.417198, test error 53.45
# Epoch   300, train loss 0.234622, train error 7.18,  test loss 3.839335, test error 55.40
# Epoch   400, train loss 0.047959, train error 0.30,  test loss 5.276649, test error 55.62
# Epoch   500, train loss 0.015467, train error 0.00,  test loss 6.293495, test error 55.85
# Epoch   600, train loss 0.009323, train error 0.00,  test loss 6.919611, test error 56.03
# Epoch   700, train loss 0.006592, train error 0.00,  test loss 7.380342, test error 56.00
# Epoch   800, train loss 0.004997, train error 0.00,  test loss 7.765367, test error 55.90
# Epoch   900, train loss 0.004037, train error 0.00,  test loss 8.066285, test error 55.95
# Training model with  55 hidden variables
# Epoch     0, train loss 2.069289, train error 76.80,  test loss 2.015650, test error 76.50
# Epoch   100, train loss 0.604141, train error 17.15,  test loss 1.660767, test error 50.38
# Epoch   200, train loss 0.216300, train error 4.97,  test loss 3.048338, test error 54.58
# Epoch   300, train loss 0.045290, train error 0.07,  test loss 4.736715, test error 55.28
# Epoch   400, train loss 0.014962, train error 0.00,  test loss 5.799928, test error 55.78
# Epoch   500, train loss 0.008794, train error 0.00,  test loss 6.424203, test error 55.67
# Epoch   600, train loss 0.005953, train error 0.00,  test loss 6.889694, test error 55.90
# Epoch   700, train loss 0.004458, train error 0.00,  test loss 7.235221, test error 55.95
# Epoch   800, train loss 0.003521, train error 0.00,  test loss 7.530551, test error 55.88
# Epoch   900, train loss 0.002879, train error 0.00,  test loss 7.770394, test error 55.95
# Training model with  60 hidden variables
# Epoch     0, train loss 2.083468, train error 77.43,  test loss 2.059343, test error 76.68
# Epoch   100, train loss 0.509408, train error 15.38,  test loss 1.752470, test error 49.83
# Epoch   200, train loss 0.088964, train error 0.60,  test loss 3.359997, test error 52.75
# Epoch   300, train loss 0.018092, train error 0.00,  test loss 4.591200, test error 53.25
# Epoch   400, train loss 0.008868, train error 0.00,  test loss 5.221622, test error 53.22
# Epoch   500, train loss 0.005705, train error 0.00,  test loss 5.638059, test error 53.25
# Epoch   600, train loss 0.004073, train error 0.00,  test loss 5.952841, test error 53.17
# Epoch   700, train loss 0.003141, train error 0.00,  test loss 6.198268, test error 53.20
# Epoch   800, train loss 0.002532, train error 0.00,  test loss 6.405102, test error 53.25
# Epoch   900, train loss 0.002101, train error 0.00,  test loss 6.578428, test error 53.30
# Training model with  70 hidden variables
# Epoch     0, train loss 2.020873, train error 75.20,  test loss 1.965416, test error 75.20
# Epoch   100, train loss 0.361199, train error 9.62,  test loss 1.897424, test error 51.45
# Epoch   200, train loss 0.033179, train error 0.00,  test loss 3.479183, test error 52.28
# Epoch   300, train loss 0.010891, train error 0.00,  test loss 4.244302, test error 52.50
# Epoch   400, train loss 0.006044, train error 0.00,  test loss 4.667264, test error 52.83
# Epoch   500, train loss 0.004091, train error 0.00,  test loss 4.965104, test error 52.92
# Epoch   600, train loss 0.003035, train error 0.00,  test loss 5.193332, test error 53.05
# Epoch   700, train loss 0.002375, train error 0.00,  test loss 5.372934, test error 53.00
# Epoch   800, train loss 0.001943, train error 0.00,  test loss 5.525194, test error 52.92
# Epoch   900, train loss 0.001632, train error 0.00,  test loss 5.656600, test error 52.95
# Training model with  80 hidden variables
# Epoch     0, train loss 2.019592, train error 73.57,  test loss 1.954270, test error 73.80
# Epoch   100, train loss 0.247814, train error 5.43,  test loss 2.072820, test error 51.05
# Epoch   200, train loss 0.020435, train error 0.00,  test loss 3.419653, test error 52.97
# Epoch   300, train loss 0.008176, train error 0.00,  test loss 3.989843, test error 52.78
# Epoch   400, train loss 0.004821, train error 0.00,  test loss 4.331077, test error 52.90
# Epoch   500, train loss 0.003327, train error 0.00,  test loss 4.573434, test error 53.03
# Epoch   600, train loss 0.002502, train error 0.00,  test loss 4.758944, test error 53.03
# Epoch   700, train loss 0.001986, train error 0.00,  test loss 4.913503, test error 53.20
# Epoch   800, train loss 0.001632, train error 0.00,  test loss 5.042276, test error 53.17
# Epoch   900, train loss 0.001379, train error 0.00,  test loss 5.152300, test error 53.20
# Training model with  90 hidden variables
# Epoch     0, train loss 1.990396, train error 75.30,  test loss 1.905053, test error 74.60
# Epoch   100, train loss 0.149517, train error 1.10,  test loss 2.162895, test error 52.10
# Epoch   200, train loss 0.015468, train error 0.00,  test loss 3.261574, test error 53.20
# Epoch   300, train loss 0.006774, train error 0.00,  test loss 3.702751, test error 53.05
# Epoch   400, train loss 0.004135, train error 0.00,  test loss 3.981269, test error 53.20
# Epoch   500, train loss 0.002900, train error 0.00,  test loss 4.180362, test error 53.15
# Epoch   600, train loss 0.002203, train error 0.00,  test loss 4.335582, test error 53.15
# Epoch   700, train loss 0.001758, train error 0.00,  test loss 4.461954, test error 53.08
# Epoch   800, train loss 0.001454, train error 0.00,  test loss 4.568822, test error 52.97
# Epoch   900, train loss 0.001234, train error 0.00,  test loss 4.660477, test error 52.97
# Training model with 100 hidden variables
# Epoch     0, train loss 1.987766, train error 73.38,  test loss 1.915969, test error 72.72
# Epoch   100, train loss 0.089232, train error 0.15,  test loss 2.272664, test error 53.33
# Epoch   200, train loss 0.012096, train error 0.00,  test loss 3.092031, test error 52.42
# Epoch   300, train loss 0.005654, train error 0.00,  test loss 3.454303, test error 52.38
# Epoch   400, train loss 0.003541, train error 0.00,  test loss 3.680253, test error 52.40
# Epoch   500, train loss 0.002523, train error 0.00,  test loss 3.847892, test error 52.30
# Epoch   600, train loss 0.001932, train error 0.00,  test loss 3.977340, test error 52.38
# Epoch   700, train loss 0.001553, train error 0.00,  test loss 4.083946, test error 52.30
# Epoch   800, train loss 0.001291, train error 0.00,  test loss 4.173777, test error 52.33
# Epoch   900, train loss 0.001100, train error 0.00,  test loss 4.252792, test error 52.25
# Training model with 120 hidden variables
# Epoch     0, train loss 1.989194, train error 73.25,  test loss 1.929504, test error 73.75
# Epoch   100, train loss 0.053520, train error 0.03,  test loss 2.275435, test error 51.58
# Epoch   200, train loss 0.009539, train error 0.00,  test loss 2.897824, test error 51.25
# Epoch   300, train loss 0.004665, train error 0.00,  test loss 3.178247, test error 51.28
# Epoch   400, train loss 0.002979, train error 0.00,  test loss 3.361583, test error 51.28
# Epoch   500, train loss 0.002144, train error 0.00,  test loss 3.497704, test error 51.38
# Epoch   600, train loss 0.001656, train error 0.00,  test loss 3.603750, test error 51.38
# Epoch   700, train loss 0.001338, train error 0.00,  test loss 3.692120, test error 51.20
# Epoch   800, train loss 0.001117, train error 0.00,  test loss 3.767389, test error 51.30
# Epoch   900, train loss 0.000954, train error 0.00,  test loss 3.831990, test error 51.25
# Training model with 140 hidden variables
# Epoch     0, train loss 1.964734, train error 72.30,  test loss 1.894583, test error 72.93
# Epoch   100, train loss 0.035857, train error 0.00,  test loss 2.171861, test error 49.85
# Epoch   200, train loss 0.007938, train error 0.00,  test loss 2.650288, test error 50.12
# Epoch   300, train loss 0.004087, train error 0.00,  test loss 2.880465, test error 49.97
# Epoch   400, train loss 0.002658, train error 0.00,  test loss 3.033663, test error 50.12
# Epoch   500, train loss 0.001936, train error 0.00,  test loss 3.147516, test error 50.05
# Epoch   600, train loss 0.001507, train error 0.00,  test loss 3.237805, test error 50.00
# Epoch   700, train loss 0.001224, train error 0.00,  test loss 3.313013, test error 50.05
# Epoch   800, train loss 0.001025, train error 0.00,  test loss 3.376528, test error 50.08
# Epoch   900, train loss 0.000879, train error 0.00,  test loss 3.432551, test error 50.10
# Training model with 160 hidden variables
# Epoch     0, train loss 1.954236, train error 72.07,  test loss 1.892484, test error 74.47
# Epoch   100, train loss 0.027990, train error 0.00,  test loss 2.173374, test error 49.60
# Epoch   200, train loss 0.007059, train error 0.00,  test loss 2.587881, test error 49.78
# Epoch   300, train loss 0.003713, train error 0.00,  test loss 2.791133, test error 49.72
# Epoch   400, train loss 0.002440, train error 0.00,  test loss 2.923665, test error 49.65
# Epoch   500, train loss 0.001789, train error 0.00,  test loss 3.025130, test error 49.65
# Epoch   600, train loss 0.001397, train error 0.00,  test loss 3.104966, test error 49.70
# Epoch   700, train loss 0.001138, train error 0.00,  test loss 3.171649, test error 49.60
# Epoch   800, train loss 0.000956, train error 0.00,  test loss 3.228993, test error 49.70
# Epoch   900, train loss 0.000821, train error 0.00,  test loss 3.278677, test error 49.60
# Training model with 180 hidden variables
# Epoch     0, train loss 1.900407, train error 69.50,  test loss 1.792874, test error 70.70
# Epoch   100, train loss 0.023292, train error 0.00,  test loss 2.020850, test error 47.35
# Epoch   200, train loss 0.006416, train error 0.00,  test loss 2.368798, test error 47.20
# Epoch   300, train loss 0.003453, train error 0.00,  test loss 2.546440, test error 47.12
# Epoch   400, train loss 0.002290, train error 0.00,  test loss 2.662760, test error 47.30
# Epoch   500, train loss 0.001688, train error 0.00,  test loss 2.750557, test error 47.35
# Epoch   600, train loss 0.001324, train error 0.00,  test loss 2.822560, test error 47.35
# Epoch   700, train loss 0.001081, train error 0.00,  test loss 2.881105, test error 47.38
# Epoch   800, train loss 0.000910, train error 0.00,  test loss 2.931870, test error 47.22
# Epoch   900, train loss 0.000783, train error 0.00,  test loss 2.975605, test error 47.25
# Training model with 200 hidden variables
# Epoch     0, train loss 1.918168, train error 70.85,  test loss 1.867748, test error 72.60
# Epoch   100, train loss 0.022578, train error 0.00,  test loss 2.008833, test error 48.03
# Epoch   200, train loss 0.006303, train error 0.00,  test loss 2.330243, test error 47.83
# Epoch   300, train loss 0.003408, train error 0.00,  test loss 2.493561, test error 47.97
# Epoch   400, train loss 0.002271, train error 0.00,  test loss 2.604024, test error 47.83
# Epoch   500, train loss 0.001676, train error 0.00,  test loss 2.687528, test error 47.80
# Epoch   600, train loss 0.001316, train error 0.00,  test loss 2.754441, test error 47.90
# Epoch   700, train loss 0.001076, train error 0.00,  test loss 2.810436, test error 47.75
# Epoch   800, train loss 0.000906, train error 0.00,  test loss 2.859187, test error 47.62
# Epoch   900, train loss 0.000779, train error 0.00,  test loss 2.901507, test error 47.62
# Training model with 250 hidden variables
# Epoch     0, train loss 1.875270, train error 67.70,  test loss 1.781782, test error 69.38
# Epoch   100, train loss 0.017224, train error 0.00,  test loss 1.924869, test error 46.70
# Epoch   200, train loss 0.005397, train error 0.00,  test loss 2.183777, test error 46.58
# Epoch   300, train loss 0.003002, train error 0.00,  test loss 2.321452, test error 46.70
# Epoch   400, train loss 0.002025, train error 0.00,  test loss 2.414988, test error 46.75
# Epoch   500, train loss 0.001507, train error 0.00,  test loss 2.485513, test error 46.65
# Epoch   600, train loss 0.001189, train error 0.00,  test loss 2.543986, test error 46.60
# Epoch   700, train loss 0.000976, train error 0.00,  test loss 2.591806, test error 46.65
# Epoch   800, train loss 0.000824, train error 0.00,  test loss 2.633314, test error 46.65
# Epoch   900, train loss 0.000711, train error 0.00,  test loss 2.669580, test error 46.62
# Training model with 300 hidden variables
# Epoch     0, train loss 1.862838, train error 67.07,  test loss 1.792641, test error 69.72
# Epoch   100, train loss 0.014482, train error 0.00,  test loss 1.842759, test error 46.85
# Epoch   200, train loss 0.004859, train error 0.00,  test loss 2.055939, test error 46.58
# Epoch   300, train loss 0.002752, train error 0.00,  test loss 2.171045, test error 46.38
# Epoch   400, train loss 0.001876, train error 0.00,  test loss 2.251587, test error 46.42
# Epoch   500, train loss 0.001404, train error 0.00,  test loss 2.312853, test error 46.50
# Epoch   600, train loss 0.001113, train error 0.00,  test loss 2.362092, test error 46.50
# Epoch   700, train loss 0.000916, train error 0.00,  test loss 2.403776, test error 46.53
# Epoch   800, train loss 0.000775, train error 0.00,  test loss 2.439181, test error 46.38
# Epoch   900, train loss 0.000670, train error 0.00,  test loss 2.471128, test error 46.33
# Training model with 400 hidden variables
# Epoch     0, train loss 1.853146, train error 67.05,  test loss 1.785806, test error 68.62
# Epoch   100, train loss 0.011772, train error 0.00,  test loss 1.767210, test error 45.92
# Epoch   200, train loss 0.004185, train error 0.00,  test loss 1.944866, test error 46.33
# Epoch   300, train loss 0.002412, train error 0.00,  test loss 2.043756, test error 45.92
# Epoch   400, train loss 0.001660, train error 0.00,  test loss 2.113438, test error 45.90
# Epoch   500, train loss 0.001251, train error 0.00,  test loss 2.165701, test error 45.78
# Epoch   600, train loss 0.000996, train error 0.00,  test loss 2.208365, test error 45.83
# Epoch   700, train loss 0.000823, train error 0.00,  test loss 2.244503, test error 45.75
# Epoch   800, train loss 0.000698, train error 0.00,  test loss 2.275373, test error 45.75
# Epoch   900, train loss 0.000605, train error 0.00,  test loss 2.302788, test error 45.83

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
